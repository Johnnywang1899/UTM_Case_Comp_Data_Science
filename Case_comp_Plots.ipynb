# %%
import numpy as np
from numpy import arange
import pandas as pd
from pandas import read_table
from pandas import set_option
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
df = pd.read_excel('Cognition & biometric data copy.xlsx',sheet_name = 'Sheet2')
df.head()
# Out:
#    Index  Date_num       Date  Sessions (2021)  Permutation  Measure_num  \
# 0      1         1  Jul 25-27                1            1            1
# 1      2         1  Jul 25-27                1            1            2
# 2      3         1  Jul 25-27                1            1            3
# 3      4         1  Jul 25-27                1            1            4
# 4      5         1  Jul 25-27                1            1            5
#
#       IR     DR  Stroop   BG  BPS  BPD   HR          Activity  Day  Time  \
# 0   80.0   62.0   125.0  4.9  116   74  126           Nothing    1  2300
# 1  102.0   83.0    97.0  6.3  131   71  107                TV    2   900
# 2   73.0   91.0   124.0  6.1   67   40  163  Aerobic Exercise    2  1500
# 3   69.0   62.0   128.0  6.4  114   71  119             Sugar    2  2300
# 4  102.0  104.0   123.0  5.4  115   60   98           Nothing    3  2300
#
#    Period   time
# 0       1  D1_11
# 1       1   D2_9
# 2       1   D2_3
# ...

# %%
df.isna().sum()
# Out:
# Index              0
# Date_num           0
# Date               0
# Sessions (2021)    0
# Permutation        0
# Measure_num        0
# IR                 1
# DR                 1
# Stroop             1
# BG                 0
# BPS                0
# BPD                0
# HR                 0
# Activity           0
# Day                0
# Time               0
# Period             0
# time               0
# dtype: int64

# %%
df = df.fillna(df.mean().iloc[0])

# %%
df.isna().sum()
# Out:
# Index              0
# Date_num           0
# Date               0
# Sessions (2021)    0
# Permutation        0
# Measure_num        0
# IR                 0
# DR                 0
# Stroop             0
# BG                 0
# BPS                0
# BPD                0
# HR                 0
# Activity           0
# Day                0
# Time               0
# Period             0
# time               0
# dtype: int64

# %%
df.head()
# Out:
#    Index  Date_num       Date  Sessions (2021)  Permutation  Measure_num  \
# 0      1         1  Jul 25-27                1            1            1
# 1      2         1  Jul 25-27                1            1            2
# 2      3         1  Jul 25-27                1            1            3
# 3      4         1  Jul 25-27                1            1            4
# 4      5         1  Jul 25-27                1            1            5
#
#       IR     DR  Stroop   BG  BPS  BPD   HR          Activity  Day  Time  \
# 0   80.0   62.0   125.0  4.9  116   74  126           Nothing    1  2300
# 1  102.0   83.0    97.0  6.3  131   71  107                TV    2   900
# 2   73.0   91.0   124.0  6.1   67   40  163  Aerobic Exercise    2  1500
# 3   69.0   62.0   128.0  6.4  114   71  119             Sugar    2  2300
# 4  102.0  104.0   123.0  5.4  115   60   98           Nothing    3  2300
#
#    Period   time
# 0       1  D1_11
# 1       1   D2_9
# 2       1   D2_3
# ...

# %%
df_p1 = df[df['Permutation'] == 1]
df_p1.head()
# Out:
#    Index  Date_num       Date  Sessions (2021)  Permutation  Measure_num  \
# 0      1         1  Jul 25-27                1            1            1
# 1      2         1  Jul 25-27                1            1            2
# 2      3         1  Jul 25-27                1            1            3
# 3      4         1  Jul 25-27                1            1            4
# 4      5         1  Jul 25-27                1            1            5
#
#       IR     DR  Stroop   BG  BPS  BPD   HR          Activity  Day  Time  \
# 0   80.0   62.0   125.0  4.9  116   74  126           Nothing    1  2300
# 1  102.0   83.0    97.0  6.3  131   71  107                TV    2   900
# 2   73.0   91.0   124.0  6.1   67   40  163  Aerobic Exercise    2  1500
# 3   69.0   62.0   128.0  6.4  114   71  119             Sugar    2  2300
# 4  102.0  104.0   123.0  5.4  115   60   98           Nothing    3  2300
#
#    Period   time
# 0       1  D1_11
# 1       1   D2_9
# 2       1   D2_3
# ...

# %%
df_p2 = df[df['Permutation'] == 2]
df_p2.head()
# Out:
#    Index  Date_num     Date  Sessions (2021)  Permutation  Measure_num     IR  \
# 5      6         2  Aug 4-6                2            2            1  102.0
# 6      7         2  Aug 4-6                2            2            2  113.0
# 7      8         2  Aug 4-6                2            2            3   91.0
# 8      9         2  Aug 4-6                2            2            4   69.0
# 9     10         2  Aug 4-6                2            2            5   91.0
#
#      DR  Stroop   BG  BPS  BPD   HR          Activity  Day  Time  Period  \
# 5  62.0   126.0  5.2  115   76  114           Nothing    1  2300       1
# 6  73.0   126.0  5.7  107   56  127           Reading    2   900       1
# 7  52.0   126.0  5.9   74   45  128  Aerobic Exercise    2  1500       1
# 8  73.0   128.0  6.4  110   70  114             Sugar    2  2300       1
# 9  62.0    96.0  6.2  120   68  111           Nothing    3  2300       1
#
#     time
# 5  D1_11
# 6   D2_9
# 7   D2_3
# 8  D2_11
# ...

# %%
df_p3 = df[df['Permutation'] == 3]
df_p3.head()
# Out:
#     Index  Date_num     Date  Sessions (2021)  Permutation  Measure_num  \
# 10     11         3  Aug 7-9                3            3            1
# 11     12         3  Aug 7-9                3            3            2
# 12     13         3  Aug 7-9                3            3            3
# 13     14         3  Aug 7-9                3            3            4
# 14     15         3  Aug 7-9                3            3            5
#
#        IR     DR  Stroop   BG  BPS  BPD   HR     Activity  Day  Time  Period  \
# 10  113.0   93.0   119.0  5.7  122   73  101      Nothing    1  2300       1
# 11  113.0   93.0   120.0  5.7  109   68   99           TV    2   900       1
# 12  102.0  104.0   126.0  5.6  107   65  106  No Exercise    2  1500       1
# 13   91.0  114.0   117.0  5.2  114   67  103     No Sugar    2  2300       1
# 14   69.0  114.0   124.0  5.1  104   68  119      Nothing    3  2300       1
#
#      time
# 10  D1_11
# 11   D2_9
# 12   D2_3
# 13  D2_11
# 14  D3_11

# %% [markdown]
# ## Permutation1

# %%
#IR for Permutation1:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p1,
    x="time", y="IR", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#DR for Permutation1:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p1,
    x="time", y="DR", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#STROOP for Permutation1:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p1,
    x="time", y="Stroop", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#HR for Permutation1:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p1,
    x="time", y="HR", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BG for Permutation1:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p1,
    x="time", y="BG", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BPD for Permutation1:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p1,
    x="time", y="BPD", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BPS for Permutation1:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p1,
    x="time", y="BPS", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %% [markdown]
# ## Permutation 2

# %%
#IR for Permutation2:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p2,
    x="time", y="IR", hue="Date", style="Date",
    markers=True, dashes=False
)
# Out:
# <AxesSubplot:xlabel='time', ylabel='IR'>

# %%
#DR for Permutation2:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p2,
    x="time", y="DR", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#STROOP for Permutation2:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p2,
    x="time", y="Stroop", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#HR for Permutation2:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p2,
    x="time", y="HR", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BG for Permutation2:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p2,
    x="time", y="BG", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BPD for Permutation2:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p2,
    x="time", y="BPD", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BPS for Permutation2:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p2,
    x="time", y="BPS", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %% [markdown]
# ## Permutation 3

# %%
#IR for Permutation3:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p3,
    x="time", y="IR", hue="Date", style="Date",
    markers=True, dashes=False
)
# Out:
# <AxesSubplot:xlabel='time', ylabel='IR'>

# %%
#DR for Permutation3:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p3,
    x="time", y="DR", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#STROOP for Permutation3:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p3,
    x="time", y="Stroop", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#HR for Permutation3:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p3,
    x="time", y="HR", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BPD for Permutation3:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p3,
    x="time", y="BPD", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BPS for Permutation3:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p3,
    x="time", y="BPS", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})

# %%
#BG for Permutation3:
plt.figure(figsize=(8,4))
sns.lineplot(
    data=df_p3,
    x="time", y="BG", hue="Date", style="Date",
    markers=True, dashes=False
)
plt.legend(loc='lower left',prop={"size":7.5})
